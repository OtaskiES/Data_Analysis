# %% [markdown]
# Run %load_ext sql first befor importing libraries

# %%
# %load_ext sql

# %% [markdown]
# Imported Library
# # greyed out libraries are not requires to connect to the database
#
# MySQLdb is preffered to MySQL connector becuase it has less connection issues.
# Also see https://jupyter-tutorial.readthedocs.io/en/stable/data-processing/postgresql/ipython-sql.html
# for more information.

# %%
#import pandas as pd
#import numpy as np
#import requests
#import matplotlib as plt
#import openpyxl
import MySQLdb
#from __future__ import print_function
#import mysql.connecto
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
from MySQLdb import _mysql

# %% [markdown]
# MySQL connection
# format
# # mysqlclient - ("mysql+mysqldb://scott:tiger@localhost/foo")
#
# # "mysql+mysqldb",
#    # username = "admin",
#    # password = "Workgroup21",
#    # host = "otaskiesdb1.c5loshwm2k8c.eu-west-2.rds.amazonaws.com",
#    # database = "v2gmodel"

# %%
# %sql mysql+mysqldb://admin:Workgroup21@otaskiesdb1.c5loshwm2k8c.eu-west-2.rds.amazonaws.com/v2gmodel

# %% [markdown]
# MySQl Magic
#
# Example - This example connect to the database and prints the first 15 lines of the database.

# %%
# %%sql mysql+mysqldb://admin:Workgroup21@otaskiesdb1.c5loshwm2k8c.eu-west-2.rds.amazonaws.com/v2gmodel
# SELECT * FROM v2gmodel.elaadnl_data limit 15
# Out:
# 15 rows affected.
# [(3261657, 'e62c50d1be0a2f80ec51d471f9630a4e', 2, '01/01/2019 00:30', '01/01/2019 08:24', '826d337c1d84900452edfcb27a3fb11bcbd06f35da8406abd9ca28b1291d219c', 7.91, 1.0, 6.53, 9.818),
#  (3262038, '9bae10789a789973cc7f05d2a96df76f', 1, '01/01/2019 10:36', '01/01/2019 12:52', '26612ba143072faddaa884c2b04208992c5f44d97e5a247dacfbce8a6b0fb9c9', 2.27, 2.27, 8.08, 3.6),
#  (3262129, '5ab468315a1f42feb6d0a87307593352', 1, '01/01/2019 11:49', '01/01/2019 17:50', '8478920deafe847713d1707d8f71a043c59fa066e55020b941c8685aa6634f64', 6.02, 3.75, 11.56, 3.4),
#  (3262170, '00fa448dfcba79a12a3cea56fb48d63f', 2, '01/01/2019 12:22', '01/01/2019 14:29', 'e8e1953d3e6221f971ce3299d2fa8275cdc9e7700e2b391485928725b7e8711e', 2.12, 0.87, 3.84, 7.973),
#  (3262208, 'e35645c6b4adb10224ecfbdff6bc5473', 1, '01/01/2019 12:51', '01/01/2019 15:16', '6490d53fbbe95d74592928292858f9b156d838f08d062e7258f1e95321dfd4e8', 2.41, 2.41, 8.5, 3.592),
# ...
